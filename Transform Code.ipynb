# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("produtos.csv",sep=";")

# %%
df.head()
# Out:
#    Unnamed: 0                                               nome        preco  \
# 0           0  Carregador USB-C de 20W Apple Branco Original ...    R$ 149,99
# 1           1  Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  R$ 1.799,10
# 2           2  Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  R$ 4.449,00
# 3           3  Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...    R$ 836,10
# 4           4  Smartphone Samsung Galaxy A06 128GB - Azul Esc...    R$ 699,30
#
#             parcela
# 0    6x de R$ 27,77
# 1  10x de R$ 197,70
# 2  10x de R$ 488,90
# 3   10x de R$ 91,87
# 4   10x de R$ 76,84

# %%
df.shape
# Out:
# (10000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   nome        10000 non-null  object
#  2   preco       10000 non-null  object
#  3   parcela     10000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
df1 = df[['nome','preco','parcela']]

# %%
display(df1)
# Out:
#                                                    nome        preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...    R$ 149,99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  R$ 1.799,10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  R$ 4.449,00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...    R$ 836,10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...    R$ 699,30
# ...                                                 ...          ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...     R$ 17,00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...     R$ 20,00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...    R$ 664,81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...     R$ 57,15
# 9999                            APPLE WATCH 10 42 JB AL  R$ 5.399,10
#
#                parcela
# 0       6x de R$ 27,77
# 1     10x de R$ 197,70
# 2     10x de R$ 488,90
# 3      10x de R$ 91,87
# 4      10x de R$ 76,84
# ...                ...
# 9995    1x de R$ 17,00
# 9996    1x de R$ 20,00
# 9997   10x de R$ 69,97
# 9998    2x de R$ 28,57
# 9999  10x de R$ 599,90
#
# [10000 rows x 3 columns]

# %%
print(repr(df1['preco'].iloc[0]))
# Out:
# 'R$\xa0149,99'

# %%
df = df.copy()
df1['preco'] = (
    df1['preco']
    .str.replace('\xa0', '', regex=False)
    .str.replace('R$', '', regex=False)
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
display(df1)
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela
# 0       6x de R$ 27,77
# 1     10x de R$ 197,70
# 2     10x de R$ 488,90
# 3      10x de R$ 91,87
# 4      10x de R$ 76,84
# ...                ...
# 9995    1x de R$ 17,00
# 9996    1x de R$ 20,00
# 9997   10x de R$ 69,97
# 9998    2x de R$ 28,57
# 9999  10x de R$ 599,90
#
# [10000 rows x 3 columns]

# %%
df1[['qtd_parcelas','valor_parcelas']] = df1['parcela'].str.split(' ',n=1,expand=True)

# %%
df1
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela qtd_parcelas valor_parcelas
# 0       6x de R$ 27,77           6x    de R$ 27,77
# 1     10x de R$ 197,70          10x   de R$ 197,70
# 2     10x de R$ 488,90          10x   de R$ 488,90
# 3      10x de R$ 91,87          10x    de R$ 91,87
# 4      10x de R$ 76,84          10x    de R$ 76,84
# ...                ...          ...            ...
# 9995    1x de R$ 17,00           1x    de R$ 17,00
# 9996    1x de R$ 20,00           1x    de R$ 20,00
# 9997   10x de R$ 69,97          10x    de R$ 69,97
# 9998    2x de R$ 28,57           2x    de R$ 28,57
# 9999  10x de R$ 599,90          10x   de R$ 599,90
#
# [10000 rows x 5 columns]

# %%
df1 = df1.copy()
df1['qtd_parcelas'] = (
    df1['qtd_parcelas']
    .str.replace('x', '', regex=False)
    .astype(int)
)

# %%
df1 = df1.copy()
df1['valor_parcelas'] = (
    df1['valor_parcelas']
    .str.replace('de', '', regex=False)
    .str.replace('R$', '', regex=False)
    .str.replace(' ', '', regex=False)
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df1
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela  qtd_parcelas  valor_parcelas
# 0       6x de R$ 27,77             6           27.77
# 1     10x de R$ 197,70            10          197.70
# 2     10x de R$ 488,90            10          488.90
# 3      10x de R$ 91,87            10           91.87
# 4      10x de R$ 76,84            10           76.84
# ...                ...           ...             ...
# 9995    1x de R$ 17,00             1           17.00
# 9996    1x de R$ 20,00             1           20.00
# 9997   10x de R$ 69,97            10           69.97
# 9998    2x de R$ 28,57             2           28.57
# 9999  10x de R$ 599,90            10          599.90
#
# [10000 rows x 5 columns]

# %%
df1['Valor Total Parcelado'] = df1['qtd_parcelas'] * df1['valor_parcelas']

# %%
df1
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela  qtd_parcelas  valor_parcelas  Valor Total Parcelado
# 0       6x de R$ 27,77             6           27.77                 166.62
# 1     10x de R$ 197,70            10          197.70                1977.00
# 2     10x de R$ 488,90            10          488.90                4889.00
# 3      10x de R$ 91,87            10           91.87                 918.70
# 4      10x de R$ 76,84            10           76.84                 768.40
# ...                ...           ...             ...                    ...
# 9995    1x de R$ 17,00             1           17.00                  17.00
# 9996    1x de R$ 20,00             1           20.00                  20.00
# 9997   10x de R$ 69,97            10           69.97                 699.70
# 9998    2x de R$ 28,57             2           28.57                  57.14
# 9999  10x de R$ 599,90            10          599.90                5999.00
#
# [10000 rows x 6 columns]

# %%
partes = df1['nome'].str.split(' ', n=2)

def juntar_partes(lista_de_partes):
    if isinstance(lista_de_partes, list):
        return ' '.join(lista_de_partes[:2])
    return np.nan  # Ou outra forma de lidar com valores que não são listas

df1['Categorias'] = partes.apply(juntar_partes)
print(df1)
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela  qtd_parcelas  valor_parcelas  Valor Total Parcelado  \
# 0       6x de R$ 27,77             6           27.77                 166.62
# 1     10x de R$ 197,70            10          197.70                1977.00
# 2     10x de R$ 488,90            10          488.90                4889.00
# 3      10x de R$ 91,87            10           91.87                 918.70
# 4      10x de R$ 76,84            10           76.84                 768.40
# ...                ...           ...             ...                    ...
# 9995    1x de R$ 17,00             1           17.00                  17.00
# 9996    1x de R$ 20,00             1           20.00                  20.00
# 9997   10x de R$ 69,97            10           69.97                 699.70
# 9998    2x de R$ 28,57             2           28.57                  57.14
# 9999  10x de R$ 599,90            10          599.90                5999.00
#
#               Categorias
# 0       Carregador USB-C
# 1     Smartphone Samsung
# 2           Apple iPhone
# 3     Smartphone Samsung
# 4     Smartphone Samsung
# ...                  ...
# 9995        Kit Película
# 9996        Kit Película
# 9997    Smartphone Blade
# 9998      Cabo Lightning
# 9999         APPLE WATCH
#
# [10000 rows x 7 columns]

# %%
display(df1)
# Out:
#                                                    nome    preco  \
# 0     Carregador USB-C de 20W Apple Branco Original ...   149.99
# 1     Smartphone Samsung Galaxy A55, 5G, 128GB, 8GB ...  1799.10
# 2     Apple iPhone 15  128GB, Quadriband, 6,1", Câme...  4449.00
# 3     Smartphone Samsung Galaxy A15, 128GB, 4GB RAM,...   836.10
# 4     Smartphone Samsung Galaxy A06 128GB - Azul Esc...   699.30
# ...                                                 ...      ...
# 9995  Kit Película Lente De Câmera Brilho Compatível...    17.00
# 9996  Kit Película Lente De Câmera Compatível Com Ip...    20.00
# 9997  Smartphone Blade Celular Para Idoso 32gb Capa ...   664.81
# 9998  Cabo Lightning Kaidi Kd-353a - Conexão Rápida ...    57.15
# 9999                            APPLE WATCH 10 42 JB AL  5399.10
#
#                parcela  qtd_parcelas  valor_parcelas  Valor Total Parcelado  \
# 0       6x de R$ 27,77             6           27.77                 166.62
# 1     10x de R$ 197,70            10          197.70                1977.00
# 2     10x de R$ 488,90            10          488.90                4889.00
# 3      10x de R$ 91,87            10           91.87                 918.70
# 4      10x de R$ 76,84            10           76.84                 768.40
# ...                ...           ...             ...                    ...
# 9995    1x de R$ 17,00             1           17.00                  17.00
# 9996    1x de R$ 20,00             1           20.00                  20.00
# 9997   10x de R$ 69,97            10           69.97                 699.70
# 9998    2x de R$ 28,57             2           28.57                  57.14
# 9999  10x de R$ 599,90            10          599.90                5999.00
#
#               Categorias
# 0       Carregador USB-C
# 1     Smartphone Samsung
# 2           Apple iPhone
# 3     Smartphone Samsung
# 4     Smartphone Samsung
# ...                  ...
# 9995        Kit Película
# 9996        Kit Película
# 9997    Smartphone Blade
# 9998      Cabo Lightning
# 9999         APPLE WATCH
#
# [10000 rows x 7 columns]

# %%
df1['Categorias'].value_counts()
# Out:
# Categorias
# Capa Capinha          2301
# Película Para          662
# Película Hidrogel      253
# Capa Para              237
# Capa De                199
#                       ...
# Smartband M8             1
# Tripé Profissional       1
# Tripé Ulanzi             1
# Adaptador USB-C          1
# Smartphone Blade         1
# Name: count, Length: 920, dtype: int64
